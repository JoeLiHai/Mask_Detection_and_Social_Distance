# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd yolov5
 
import torch
from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets
 
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.9.0+cu102 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/yolo/data
# Out:
# archive.zip  convert_annotations.py  datadownloadv5.ipynb  暫放
# classes.txt  datadownloadv4.ipynb    plate_car.zip

# %%
# copy over both datasets into the root directory of the Colab VM (comment out test.zip if you are not using a validation dataset)
# !cp /content/drive/MyDrive/yolo/yolov5/human_detection/human_plate.zip /content

# %%
# unzip the datasets and their contents so that they are now in /content/darknet/data/ folder
# !unzip /content/drive/MyDrive/yolo/yolov5/face_mask_detection/mask_plate_plus.zip -d /content/
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: /content/__MACOSX/mask_plate_plus/images/train/._700_402.jpg
#   inflating: /content/mask_plate_plus/images/train/700_403.jpg
#   inflating: /content/__MACOSX/mask_plate_plus/images/train/._700_403.jpg
#   inflating: /content/mask_plate_plus/images/train/700_404.jpg
#   inflating: /content/__MACOSX/mask_plate_plus/images/train/._700_404.jpg
#   inflating: /content/mask_plate_plus/images/train/700_405.jpg
#   inflating: /content/__MACOSX/mask_plate_plus/images/train/._700_405.jpg
#   inflating: /content/mask_plate_plus/images/train/700_406.jpg
#   inflating: /content/__MACOSX/mask_plate_plus/images/train/._700_406.jpg
#   inflating: /content/mask_plate_plus/images/train/700_407.jpg
#   inflating: /content/__MACOSX/mask_plate_plus/images/train/._700_407.jpg
#   inflating: /content/mask_plate_plus/images/train/700_408.jpg
#   inflating: /content/__MACOSX/mask_plate_plus/images/train/._700_408.jpg
# ...

# %%
# !python train.py --img 512 --batch 12 --epochs 50 --data /content/drive/MyDrive/yolo/yolov5/plate.yaml --cfg /content/drive/MyDrive/yolo/yolov5/yolov5x.yaml --weights yolov5x.pt --name ''
# Out:
# train: weights=yolov5x.pt, cfg=/content/drive/MyDrive/yolo/yolov5/yolov5x.yaml, data=/content/drive/MyDrive/yolo/yolov5/plate.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=12, img_size=[512], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-289-g720aaa6 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
##########
# !python train.py --img 720 --batch 12 --epochs 50 --data /content/drive/MyDrive/yolo/yolov5/plate.yaml --cfg /content/drive/MyDrive/yolo/yolov5/yolov5x.yaml --weights yolov5x.pt --name ''

# %%
# !cp /content/yolov5/runs/train2 -r /content/drive/MyDrive

# %%
# !cp 'runs/train/weights/best.pt' /content/drive/MyDrive/yolo/yolov5/face_mask_detection
# !cp 'runs/train/weights/last.pt' /content/drive/MyDrive/yolo/yolov5/face_mask_detection

# %%
# !cp '/content/yolov5/runs/train' -r /content/drive/MyDrive/yolo/yolov5/face_mask_detection

# %%
# !python train.py --img 512 --batch 12 --epochs 20 --data /content/drive/MyDrive/yolo/yolov5/plate.yaml --cfg /content/drive/MyDrive/yolo/yolov5/yolov5x.yaml --weights yolov5x.pt --name ''

# %%
# !python train.py --img 512 --batch 12 --epochs 20 --data /content/drive/MyDrive/yolo/yolov5/plate.yaml --cfg /content/drive/MyDrive/yolo/yolov5/yolov5x.yaml --weights /content/drive/MyDrive/yolo/yolov5/face_mask_detection/facemask_0702.pt --name ''

# %%
# !python test.py --weights /content/drive/MyDrive/yolo/yolov5/human_detection/human_0702.pt --data coco.yaml --img 512 --augment

# %%
# !cp /content/drive/MyDrive/yolo/yolov5/human_detection/Archive.zip -d /content

# %%
# !unzip /content/Archive.zip -d /content

# %%
# !cp /content/drive/MyDrive/ai_project/ttt.mp4 /content

# %%
# !unzip /content/drive/MyDrive/yolo/yolov5/face_mask_detection/08_m_plate.zip -d /content

# %%
# !python detect.py --weights /content/drive/MyDrive/human_0702.pt --img 512 --conf 0.5 --source '/content/family.jpg'
#!python detect.py --weights /content/drive/MyDrive/ai_project/train_mask_bi/weights/best.pt --img 512 --conf 0.5 --source '/content/family.jpg'# --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/human_0702.pt'], source=/content/family.jpg, imgsz=512, conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-287-gd204a61 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !cp -r /content/yolov5/runs/detect/exp3/labels /content/drive/MyDrive/yolo

# %%
# !cp -r /content/yolov5/runs/train2 /content/drive/MyDrive/yolo/yolov5/face_mask_detection

# %% [markdown]
# Reference: https://github.com/ultralytics/yolov5

# %%
# https://github.com/ultralytics/yolov5/issues/388
